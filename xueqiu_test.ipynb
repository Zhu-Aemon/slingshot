# %%
import pandas as pd
import numpy as np
import requests


def fetch_data(symbol, page=1, count=20, comment=0, hl=0, source='all', sort='alpha', q='', type_=11):
    """
    Fetch data from the specified API.
    https://xueqiu.com/query/v1/symbol/search/status.json?count=10&comment=0&symbol=SZ002085&hl=0&source=all&sort=alpha&page=1&q=&type=11
    :param symbol: The stock symbol to query.
    :param page: The page number of the results.
    :param count: The number of results per page.
    :param comment: Whether to include comments.
    :param hl: Highlight option.
    :param source: The source of the data.
    :param sort: The sorting method of the results.
    :param q: The search query.
    :param type_: The type of the query.
    :return: The JSON response from the API.
    """
    url = "https://xueqiu.com/query/v1/symbol/search/status.json"
    params = {
        "symbol": symbol,
        "page": page,
        "count": count,
        "comment": comment,
        "hl": hl,
        "source": source,
        "sort": sort,
        "q": q,
        "type": type_
    }
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36",
        "Cookie": "xqat=52dfb79aed5f2cdd1e7c2cfc56054ac1f5b77fc3"
    }
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": "Failed to fetch data", "status_code": response.status_code}


test = fetch_data(symbol='SH603721')
test
# Out:
# {'about': 'SH603721',
#  'count': 1000,
#  'key': 'SH603721',
#  'list': [{'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1711069216000,
#    'description': '<a href="http://xueqiu.com/k?q=%23Kimi%E6%A6%82%E5%BF%B5%E8%82%A1%E5%8F%91%E5%B8%83%E6%BE%84%E6%B8%85%E5%85%AC%E5%91%8A%EF%BC%8C%E6%96%87%E5%A8%B1%E4%BC%A0%E5%AA%92%E6%9D%BF%E5%9D%97%E4%BB%8A%E5%A4%A9%E6%80%8E%E4%B9%88%E8%B5%B0%EF%BC%9F%23" target="_blank">#Kimi概念股发布澄清公告，文娱传媒板块今天怎么走？#</a> 近日，Kimi概念股大涨，华策影视<a href="http://xueqiu.com/S/SZ300133" target="_blank">$华策影视(SZ300133)$</a> 、掌阅科技<a href="http://xueqiu.com/S/SH603533" target="_blank">$掌阅科技(SH603533)$</a> 、中广天择<a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a> 等个股连续两天“一”字涨停，相关ETF：游戏ETF、文娱传媒ETF也连续走强。<br/>面对短期的市场热炒，3月21日晚间，上述...',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'excellent_comments': [{'blocked': False,
#      'blocking': False,
#      'canEdit': True,
#      'censored': False,
#      'client': 'WiCimxpj5H',
#      'createdAt': 1711069411000,
#      'description': '<a href="http://xueqiu.com/S/SZ159869" target="_blank">$游戏ETF(SZ159869)$</a><br/>我很看好游戏板块未来的投资机会。<br/>游戏行业是非常注重创新的行业，随着AI，VR等技术的进步和消费者需求的多样化，游戏行业的市场规模和影响力不断扩大，特别是在海外市场和新兴领域如VR，AR游戏等方面，存在较大的发展空间。<br/>从短期来看，新游发行节奏修复带动供...',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'donate_user_count': 0,
#      'id': 320337430,
#      'inReplyToCommentId': 0,
#      'indexText': ' $游戏ETF(SZ159869)$  我很看好游戏板块未来的投资机会。 游戏行业是非常注重创新的行业，随着AI，VR等技术的进步和消费者需求的多样化，游戏行业的市场规模和影响力不断扩大，特别是在海外市场和新兴领域如VR，AR游戏等方面，存在较大的发展空间。 从短期来看，新游发行节奏修复带动供需格局优化，提升公司业绩，随着游戏版号发放进入常态化，游戏行业稳定性得到增强，前期积压的部分游戏在今年密集发行，新产品周期即将到来，消费者信心增强，游戏消费需求有望显著修复。 从长期来看，AIGC成为市场热点，游戏与AI结合大有可为，游戏行业凭借自身的技术优势，有望成为AI技术发展的重要应用场景之一，未来将成为AI技术商业化应用的主阵地，AI有望带来游戏行业的降本增效，创新游戏玩法，扩大用户人群，进而打开估值空间。',
#      'likeCount': 4,
#      'originalText': '<a href="http://xueqiu.com/S/SZ159869" target="_blank">$游戏ETF(SZ159869)$</a><br/>我很看好游戏板块未来的投资机会。<br/>游戏行业是非常注重创新的行业，随着AI，VR等技术的进步和消费者需求的多样化，游戏行业的市场规模和影响力不断扩大，特别是在海外市场和新兴领域如VR，AR游戏等方面，存在较大的发展空间。<br/>从短期来看，新游发行节奏修复带动供需格局优化，提升公司业绩，随着游戏版号发放进入常态化，游戏行业稳定性得到增强，前期积压的部分游戏在今年密集发行，新产品周期即将到来，消费者信心增强，游戏消费需求有望显著修复。<br/>从长期来看，AIGC成为市场热点，游戏与AI结合大有可为，游戏行业凭借自身的技术优势，有望成为AI技术发展的重要应用场景之一，未来将成为AI技术商业化应用的主阵地，AI有望带来游戏行业的降本增效，创新游戏玩法，扩大用户人群，进而打开估值空间。',
#      'pic': '',
#      'picSizes': [],
#      'reply_remark': '',
#      'reply_screenName': '',
#      'reply_verified': False,
#      'reply_verified_description': '',
#      'rootInReplyToStatusId': 283055837,
#      'source': '股票微博',
#      'source_view': '雪球',
#      'statusId': 0,
#      'text': '<a href="http://xueqiu.com/S/SZ159869" target="_blank">$游戏ETF(SZ159869)$</a><br/>我很看好游戏板块未来的投资机会。<br/>游戏行业是非常注重创新的行业，随着AI，VR等技术的进步和消费者需求的多样化，游戏行业的市场规模和影响力不断扩大，特别是在海外市场和新兴领域如VR，AR游戏等方面，存在较大的发展空间。<br/>从短期来看，新游发行节奏修复带动供需格局优化，提升公司业绩，随着游戏版号发放进入常态化，游戏行业稳定性得到增强，前期积压的部分游戏在今年密集发行，新产品周期即将到来，消费者信心增强，游戏消费需求有望显著修复。<br/>从长期来看，AIGC成为市场热点，游戏与AI结合大有可为，游戏行业凭借自身的技术优势，有望成为AI技术发展的重要应用场景之一，未来将成为AI技术商业化应用的主阵地，AI有望带来游戏行业的降本增效，创新游戏玩法，扩大用户人群，进而打开估值空间。',
#      'time_before': '今天 09:03',
#      'truncated': False,
#      'truncatedBy': 0,
#      'user': {'allow_all_stock': False,
#       'block_status': 0,
#       'blocking': False,
#       'city': '',
#       'common_count': 0,
#       'description': '',
#       'donate_count': 0,
#       'follow_me': False,
#       'followers_count': 18,
#       'following': False,
#       'fortuneUser': False,
#       'friends_count': 1099,
#       'gender': 'n',
#       'id': 3283647298,
#       'last_comment_id': 320363691,
#       'last_status_id': 280850395,
#       'photo_domain': 'http://xavatar.imedao.com/',
#       'profile': '/3283647298',
#       'profile_image_url': 'community/20232/1680003468338-1680003468634.jpg,community/20232/1680003468338-1680003468634.jpg!180x180.png,community/20232/1680003468338-1680003468634.jpg!50x50.png,community/20232/1680003468338-1680003468634.jpg!30x30.png',
#       'screen_name': '泗洲河畔',
#       'st_color': '1',
#       'status': 0,
#       'status_count': 0,
#       'step': 'null',
#       'subscribeable': False,
#       'type': '1',
#       'user': {'allow_all_stock': False,
#        'anonymous': False,
#        'areaCode': '86',
#        'blocking': False,
#        'city': '',
#        'created_at': 1680003076709,
#        'description': '',
#        'donate_count': 0,
#        'donate_snowcoin': 0,
#        'follow_me': False,
#        'followers_count': 18,
#        'following': False,
#        'friends_count': 1099,
#        'gender': 'n',
#        'id': 3283647298,
#        'last_comment_id': 320363691,
#        'last_status_id': 280850395,
#        'photo_domain': 'http://xavatar.imedao.com/',
#        'profile': '/3283647298',
#        'profile_image_url': 'community/20232/1680003468338-1680003468634.jpg,community/20232/1680003468338-1680003468634.jpg!180x180.png,community/20232/1680003468338-1680003468634.jpg!50x50.png,community/20232/1680003468338-1680003468634.jpg!30x30.png',
#        'screen_name': '泗洲河畔',
#        'st_color': '1',
#        'status': 0,
#        'status_count': 0,
#        'step': 'null',
#        'truncated': False,
#        'type': '1',
#        'verified': False,
#        'verified_description': '',
#        'verified_type': 0},
#       'verified': False,
#       'verified_description': '',
#       'verified_realname': False,
#       'verified_type': 0},
#      'userId': 3283647298}],
#    'expend': True,
#    'fav_count': 2,
#    'favorited': False,
#    'firstImg': 'https://xqimg.imedao.com/18e63a86e1d85d733fd56764.png!thumb.jpg',
#    'flags': 36028934457917472,
#    'flagsObj': {'flags': 36028934457917472},
#    'hot': False,
#    'id': 283055837,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 16,
#    'liked': False,
#    'mark': 0,
#    'offer': {'amount': 1888,
#     'balance': 1888,
#     'count': 0,
#     'desc': '提问者将在悬赏截止前分配赏金，截止至03/27 09:00',
#     'dueTime': 1711501216333,
#     'id': 169871,
#     'refundAmount': 0,
#     'setAmount': True,
#     'setBalance': True,
#     'setCount': True,
#     'setDesc': True,
#     'setDueTime': True,
#     'setId': True,
#     'setRefundAmount': True,
#     'setState': True,
#     'setTitle': True,
#     'setType': True,
#     'state': 'NORMAL',
#     'title': '',
#     'type': 'MANUAL'},
#    'pic': 'https://xqimg.imedao.com/18e63a86e1d85d733fd56764.png!thumb.jpg,https://xqimg.imedao.com/18e63a904585b2c73fdf12c1.png!thumb.jpg',
#    'pic_sizes': [{'height': 729,
#      'ratio': '1.06',
#      'score': 0,
#      'setHeight': True,
#      'setRatio': True,
#      'setScore': True,
#      'setWidth': True,
#      'width': 770},
#     {'height': 725,
#      'ratio': '1.03',
#      'score': 0,
#      'setHeight': True,
#      'setRatio': True,
#      'setScore': True,
#      'setWidth': True,
#      'width': 747}],
#    'promotion_id': 0,
#    'reply_count': 42,
#    'retweet_count': 0,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': '雪球',
#    'source_feed': False,
#    'target': '/3951090421/283055837',
#    'text': '<p><a href="http://xueqiu.com/k?q=%23Kimi%E6%A6%82%E5%BF%B5%E8%82%A1%E5%8F%91%E5%B8%83%E6%BE%84%E6%B8%85%E5%85%AC%E5%91%8A%EF%BC%8C%E6%96%87%E5%A8%B1%E4%BC%A0%E5%AA%92%E6%9D%BF%E5%9D%97%E4%BB%8A%E5%A4%A9%E6%80%8E%E4%B9%88%E8%B5%B0%EF%BC%9F%23" target="_blank">#Kimi概念股发布澄清公告，文娱传媒板块今天怎么走？#</a> 近日，Kimi概念股大涨，华策影视<a href="http://xueqiu.com/S/SZ300133" target="_blank">$华策影视(SZ300133)$</a> 、掌阅科技<a href="http://xueqiu.com/S/SH603533" target="_blank">$掌阅科技(SH603533)$</a> 、中广天择<a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a> 等个股连续两天“一”字涨停，相关ETF：游戏ETF、文娱传媒ETF也连续走强。<br/></p><img src="https://xqimg.imedao.com/18e63a86e1d85d733fd56764.png!custom.jpg" class="ke_img" ><img src="https://xqimg.imedao.com/18e63a904585b2c73fdf12c1.png!custom.jpg" class="ke_img" ><p>面对短期的市场热炒，3月21日晚间，上述三家公司均在股票异动公告中对Kimi相关概念予以澄清和回应。</p><p><b>华策影视</b>公告称，经公司自查并向公司管理层核实，公司目前经营状况正常，内外部经营环境未发生重大变化，无应披露而未披露的重大事项；公司没有需要澄清或回应的媒体报道或市场传闻；也未出现其他可能对公司股价产生较大影响的重大事件。</p><p><b>掌阅科技</b>公告称，公司主营业务未发生重大变化，生产经营活动正常，所处的市场环境、行业政策未发生重大调整；关于有关媒体报道公司已接入国内AI大模型产品的情况说明如下：公司有在将市场已有的AI大模型和阅读APP进行融合，包括阅读前的推荐、阅读中的互动、阅读后的知识图谱等，相关产品正在内部研发和迭代之中，何时推向市场存在不确定性，预计对公司目前业务及经营情况不存在重大影响。</p><p><b>中广天择</b>公告称，主要从事综艺、纪录片、影视剧、短视频等视频内容的生产和运营。中广天择公告，近期，有媒体报道公司涉及“Sora概念股”，公司仅出售视频版权给从事大模型业务的客户，不涉及相关AI业务及AI技术；此外，公司短剧业务2024年才开展，作为新业务是否盈利存在不确定性，目前短剧业务收入极小，营收占比不足0.1%，尚未盈利。</p><p>（来源：界面新闻）</p><p>风险提示：以上涉及个股不作为推荐。ETF二级市场价格涨跌不代表基金实际净值表现。市场有风险，投资需谨慎。</p>',
#    'timeBefore': '今天 09:00',
#    'title': '',
#    'trackJson': '{"fav_count":2,"created_at":1711069216000,"reply_count":42,"client_name":"雪球","retweet_count":0,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '2',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '不限',
#     'common_count': 0,
#     'corpName': '华夏基金管理有限公司',
#     'description': '华夏基金旗下权益ETF管理规模超3900亿元，年均规模连续19年稳居行业第一；境内唯一连续7年获评“被动投资金牛基金公司”\n\n1.规模数据来自上交所、深交所、Wind，截至2023.12.31，“连续19年”指2005-2023，“年均规模”指当年各季度规模算术平均；\n2.颁奖机构：中国证券报（2016-2022），基金评价结果不预示未来表现，不构成投资建议。',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 90096,
#     'following': False,
#     'fortuneUser': True,
#     'friends_count': 1060,
#     'gender': 'n',
#     'id': 3951090421,
#     'last_comment_id': 320251717,
#     'last_status_id': 283088231,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/3951090421',
#     'profile_image_url': 'community/20241/1706843127089-1706843139306.png,community/20241/1706843127089-1706843139306.png!180x180.png,community/20241/1706843127089-1706843139306.png!50x50.png,community/20241/1706843127089-1706843139306.png!30x30.png',
#     'province': '北京',
#     'screen_name': '华夏ETF',
#     'st_color': '1',
#     'status': 1,
#     'status_count': 12252,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '3',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'blocking': False,
#      'city': '不限',
#      'corpName': '华夏基金管理有限公司',
#      'created_at': 1456653957168,
#      'description': '华夏基金旗下权益ETF管理规模超3900亿元，年均规模连续19年稳居行业第一；境内唯一连续7年获评“被动投资金牛基金公司”\n\n1.规模数据来自上交所、深交所、Wind，截至2023.12.31，“连续19年”指2005-2023，“年均规模”指当年各季度规模算术平均；\n2.颁奖机构：中国证券报（2016-2022），基金评价结果不预示未来表现，不构成投资建议。',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 90096,
#      'following': False,
#      'friends_count': 1060,
#      'gender': 'n',
#      'id': 3951090421,
#      'last_comment_id': 320251717,
#      'last_status_id': 283088231,
#      'maskedEmail': 'zha***@chinaamc.com',
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/3951090421',
#      'profile_image_url': 'community/20241/1706843127089-1706843139306.png,community/20241/1706843127089-1706843139306.png!180x180.png,community/20241/1706843127089-1706843139306.png!50x50.png,community/20241/1706843127089-1706843139306.png!30x30.png',
#      'province': '北京',
#      'screen_name': '华夏ETF',
#      'st_color': '1',
#      'status': 1,
#      'status_count': 12252,
#      'step': 'null',
#      'truncated': False,
#      'type': '3',
#      'verified': True,
#      'verified_description': '华夏基金官方账号',
#      'verified_infos': [{'verified_desc': '华夏基金官方账号', 'verified_type': '4'}],
#      'verified_type': 3},
#     'verified': True,
#     'verified_description': '华夏基金官方账号',
#     'verified_infos': [{'verified_desc': '华夏基金官方账号', 'verified_type': '4'}],
#     'verified_realname': False,
#     'verified_type': 3},
#    'user_id': 3951090421,
#    'view_count': 41761},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': False,
#    'commentId': 319444939,
#    'controversial': False,
#    'created_at': 1710380212000,
#    'description': '回复<a href="http://xueqiu.com/n/NK007" target="_blank">@NK007</a>: 其实昨晚研究后放弃了中文，而603721相反更好//<a href="http://xueqiu.com/n/NK007" target="_blank">@NK007</a>:回复<a href="http://xueqiu.com/n/玄素双行" target="_blank">@玄素双行</a>:<img src="http://js.xueqiu.com/ugc/images/face/emoji_80_doge.png?v=1" title="[狗头]" alt="[狗头]" height="24" /><img src="http://js.xueqiu.com/ugc/images/face/emoji_80_doge.png?v=1" title="[狗头]" alt="[狗头]" height="24" />不做造车了，看看特斯拉，这不是个有必要搞得行业了',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': False,
#    'expend': False,
#    'fav_count': 0,
#    'favorited': False,
#    'flags': 1236950581248,
#    'flagsObj': {'flags': 1236950581248},
#    'hot': False,
#    'id': 281977492,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 0,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 143,
#    'retweet_count': 0,
#    'retweet_status_id': 281428862,
#    'retweeted_status': {'blocked': False,
#     'blocking': False,
#     'canEdit': True,
#     'commentId': 0,
#     'controversial': False,
#     'created_at': 1710001681000,
#     'description': '<a href="http://xueqiu.com/S/SZ000063" target="_blank">$中兴通讯(SZ000063)$</a> 不知不觉中兴通讯上市28年了…新的故事即将开始，以前和华子亦敌亦友，未来何不携手共进！该是捡金子的时候了！<img src="http://js.xueqiu.com/ugc/images/face/emoji_73_gossip.png?v=1" title="[吃瓜]" alt="[吃瓜]" height="24" />',
#     'donate_count': 0,
#     'donate_snowcoin': 0,
#     'editable': True,
#     'edited_at': 1710003553000,
#     'expend': True,
#     'fav_count': 4,
#     'favorited': False,
#     'firstImg': 'https://xqimg.imedao.com/18e240aec69477b63fc749ea.jpeg!thumb.jpg',
#     'flags': 36030033969545216,
#     'flagsObj': {'flags': 36030033969545216},
#     'hot': False,
#     'id': 281428862,
#     'is_answer': False,
#     'is_bonus': False,
#     'is_refused': False,
#     'is_reward': True,
#     'is_ss_multi_pic': False,
#     'legal_user_visible': False,
#     'like_count': 7,
#     'liked': False,
#     'mark': 0,
#     'pic': 'https://xqimg.imedao.com/18e240aec69477b63fc749ea.jpeg!thumb.jpg',
#     'pic_sizes': [{'height': 1080,
#       'ratio': '2.17',
#       'score': 0,
#       'setHeight': True,
#       'setRatio': True,
#       'setScore': True,
#       'setWidth': True,
#       'width': 2340}],
#     'promotion_id': 0,
#     'reply_count': 343,
#     'retweet_count': 0,
#     'retweet_status_id': 0,
#     'reward_count': 0,
#     'reward_user_count': 0,
#     'rqid': 0,
#     'source': 'Android',
#     'source_feed': False,
#     'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#     'target': '/1265127896/281428862',
#     'text': '<a href="http://xueqiu.com/S/SZ000063" target="_blank">$中兴通讯(SZ000063)$</a> 不知不觉中兴通讯上市28年了…新的故事即将开始，以前和华子亦敌亦友，未来何不携手共进！该是捡金子的时候了！<img src="http://js.xueqiu.com/ugc/images/face/emoji_73_gossip.png?v=1" title="[吃瓜]" alt="[吃瓜]" height="24" /><br/><img class="ke_img" src="https://xqimg.imedao.com/18e240aec69477b63fc749ea.jpeg!custom.jpg" />',
#     'timeBefore': '03-10 00:28',
#     'title': '',
#     'trackJson': '{"fav_count":4,"created_at":1710001681000,"reply_count":343,"client_name":"Android","retweet_count":0,"reward_count":0}',
#     'truncated': False,
#     'truncated_by': 0,
#     'type': '0',
#     'user': {'allow_all_stock': False,
#      'block_status': 0,
#      'blocking': False,
#      'city': '不限',
#      'common_count': 0,
#      'description': '天雨虽大，不润无根之草；道法虽宽，不渡无缘之人。',
#      'donate_count': 0,
#      'follow_me': False,
#      'followers_count': 595,
#      'following': False,
#      'fortuneUser': False,
#      'friends_count': 147,
#      'gender': 'm',
#      'id': 1265127896,
#      'last_comment_id': 320367400,
#      'last_status_id': 283100136,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/1265127896',
#      'profile_image_url': 'community/20241/1709010084044-1709010084221.jpeg,community/20241/1709010084044-1709010084221.jpeg!180x180.png,community/20241/1709010084044-1709010084221.jpeg!50x50.png,community/20241/1709010084044-1709010084221.jpeg!30x30.png',
#      'province': '其他',
#      'screen_name': '玄素双行',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 1053,
#      'step': 'null',
#      'subscribeable': False,
#      'type': '1',
#      'user': {'allow_all_stock': False,
#       'anonymous': False,
#       'areaCode': '86',
#       'blocking': False,
#       'city': '不限',
#       'created_at': 1564761385845,
#       'description': '天雨虽大，不润无根之草；道法虽宽，不渡无缘之人。',
#       'donate_count': 0,
#       'donate_snowcoin': 0,
#       'follow_me': False,
#       'followers_count': 595,
#       'following': False,
#       'friends_count': 147,
#       'gender': 'm',
#       'id': 1265127896,
#       'last_comment_id': 320367400,
#       'last_status_id': 283100136,
#       'photo_domain': 'http://xavatar.imedao.com/',
#       'profile': '/1265127896',
#       'profile_image_url': 'community/20241/1709010084044-1709010084221.jpeg,community/20241/1709010084044-1709010084221.jpeg!180x180.png,community/20241/1709010084044-1709010084221.jpeg!50x50.png,community/20241/1709010084044-1709010084221.jpeg!30x30.png',
#       'province': '其他',
#       'screen_name': '玄素双行',
#       'st_color': '1',
#       'status': 0,
#       'status_count': 1053,
#       'step': 'null',
#       'truncated': False,
#       'type': '1',
#       'verified': False,
#       'verified_description': '',
#       'verified_type': 0},
#      'verified': False,
#      'verified_description': '',
#      'verified_realname': False,
#      'verified_type': 0},
#     'user_id': 1265127896,
#     'view_count': 18065},
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'Android',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/1265127896/281977492',
#    'text': '回复<a href="http://xueqiu.com/n/NK007" target="_blank">@NK007</a>: 其实昨晚研究后放弃了中文，而603721相反更好//<a href="http://xueqiu.com/n/NK007" target="_blank">@NK007</a>:回复<a href="http://xueqiu.com/n/玄素双行" target="_blank">@玄素双行</a>:<img src="http://js.xueqiu.com/ugc/images/face/emoji_80_doge.png?v=1" title="[狗头]" alt="[狗头]" height="24" /><img src="http://js.xueqiu.com/ugc/images/face/emoji_80_doge.png?v=1" title="[狗头]" alt="[狗头]" height="24" />不做造车了，看看特斯拉，这不是个有必要搞得行业了',
#    'timeBefore': '03-14 09:36',
#    'title': '',
#    'trackJson': '{"fav_count":0,"created_at":1710380212000,"reply_count":143,"client_name":"Android","retweet_count":0,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '不限',
#     'common_count': 0,
#     'description': '天雨虽大，不润无根之草；道法虽宽，不渡无缘之人。',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 595,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 147,
#     'gender': 'm',
#     'id': 1265127896,
#     'last_comment_id': 320367400,
#     'last_status_id': 283100136,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/1265127896',
#     'profile_image_url': 'community/20241/1709010084044-1709010084221.jpeg,community/20241/1709010084044-1709010084221.jpeg!180x180.png,community/20241/1709010084044-1709010084221.jpeg!50x50.png,community/20241/1709010084044-1709010084221.jpeg!30x30.png',
#     'province': '其他',
#     'screen_name': '玄素双行',
#     'st_color': '1',
#     'status': 0,
#     'status_count': 1053,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '不限',
#      'created_at': 1564761385845,
#      'description': '天雨虽大，不润无根之草；道法虽宽，不渡无缘之人。',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 595,
#      'following': False,
#      'friends_count': 147,
#      'gender': 'm',
#      'id': 1265127896,
#      'last_comment_id': 320367400,
#      'last_status_id': 283100136,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/1265127896',
#      'profile_image_url': 'community/20241/1709010084044-1709010084221.jpeg,community/20241/1709010084044-1709010084221.jpeg!180x180.png,community/20241/1709010084044-1709010084221.jpeg!50x50.png,community/20241/1709010084044-1709010084221.jpeg!30x30.png',
#      'province': '其他',
#      'screen_name': '玄素双行',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 1053,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 1265127896,
#    'view_count': 19044},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1710303498000,
#    'description': '整理记录一下我自己关注的应用端（只是我自己关注喜欢的，肯定有很多没研究到漏掉的）<br/>影视/短剧类：中广天择、中文在线、上海电影、百纳千成<br/>文字类：掌阅科技（Kimi/新晋龙头）、果麦文化<br/>代理/广告类：因赛集团、三维通信<br/>技术类：当虹科技<br/>游戏类：掌趣科技、盛天网络<br/...',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'edited_at': 1710305931000,
#    'expend': True,
#    'fav_count': 82,
#    'favorited': False,
#    'flags': 36030033969545216,
#    'flagsObj': {'flags': 36030033969545216},
#    'hot': False,
#    'id': 281856166,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 73,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 29,
#    'retweet_count': 9,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': '雪球',
#    'source_feed': False,
#    'target': '/5235921801/281856166',
#    'text': '<p>整理记录一下我自己关注的应用端（只是我自己关注喜欢的，肯定有很多没研究到漏掉的）</p><p>影视/短剧类：中广天择、中文在线、上海电影、百纳千成</p><p>文字类：掌阅科技（Kimi/新晋龙头）、果麦文化</p><p>代理/广告类：因赛集团、三维通信</p><p>技术类：当虹科技</p><p>游戏类：掌趣科技、盛天网络</p><p>教育：盛通股份、世纪天鸿</p><p>容量风格：RMW</p>',
#    'timeBefore': '03-13 12:18',
#    'title': '',
#    'trackJson': '{"fav_count":82,"created_at":1710303498000,"reply_count":29,"client_name":"雪球","retweet_count":9,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '0',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '城市/地区',
#     'common_count': 0,
#     'description': '到大事业中去\n到大事业的关键进程中去\n到大故事中去\n到大故事的主线剧情中去',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 21248,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 301,
#     'gender': 'n',
#     'id': 5235921801,
#     'last_comment_id': 320185706,
#     'last_status_id': 282862153,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/5235921801',
#     'profile_image_url': 'community/20239/1698640812411-1698640817549.png,community/20239/1698640812411-1698640817549.png!180x180.png,community/20239/1698640812411-1698640817549.png!50x50.png,community/20239/1698640812411-1698640817549.png!30x30.png',
#     'province': '省/直辖市',
#     'screen_name': '花匠秀',
#     'st_color': '1',
#     'status': 0,
#     'status_count': 4252,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '城市/地区',
#      'created_at': 1505779789920,
#      'description': '到大事业中去\n到大事业的关键进程中去\n到大故事中去\n到大故事的主线剧情中去',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 21248,
#      'following': False,
#      'friends_count': 301,
#      'gender': 'n',
#      'id': 5235921801,
#      'last_comment_id': 320185706,
#      'last_status_id': 282862153,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/5235921801',
#      'profile_image_url': 'community/20239/1698640812411-1698640817549.png,community/20239/1698640812411-1698640817549.png!180x180.png,community/20239/1698640812411-1698640817549.png!50x50.png,community/20239/1698640812411-1698640817549.png!30x30.png',
#      'province': '省/直辖市',
#      'screen_name': '花匠秀',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 4252,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#        'verified_type': '5'}],
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_infos': [{'verified_desc': '用户已完成实名身份认证', 'verified_type': '5'}],
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 5235921801,
#    'view_count': 130780},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1710909169000,
#    'description': '华策影视：接入月之暗面大模型<br/>海天瑞声：为kimi提供数据训练服务<br/>掌阅科技：接入月之暗面kimi<br/>中文在线：拥有可用于模型的IP数据<br/>补充：<br/>孩子王：预期接入kimi，kimi想要孩子王的育儿数据扩展大模型的to C应用端。<br/>九安医疗：公司是砺思资本的有限合伙人，砺思资本参股了...',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'edited_at': 1710928268000,
#    'excellent_comments': [{'blocked': False,
#      'blocking': False,
#      'canEdit': True,
#      'censored': False,
#      'client': 'd9d0n4AZup',
#      'createdAt': 1710909347000,
#      'description': '应该是中广天泽',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'donate_user_count': 0,
#      'id': 320108202,
#      'inReplyToCommentId': 0,
#      'indexText': '应该是中广天泽',
#      'likeCount': 2,
#      'originalText': '应该是中广天泽',
#      'pic': '',
#      'picSizes': [],
#      'reply_remark': '',
#      'reply_screenName': '',
#      'reply_verified': False,
#      'reply_verified_description': '',
#      'rootInReplyToStatusId': 282771985,
#      'source': '股票微博',
#      'source_view': '雪球',
#      'statusId': 282772317,
#      'text': '应该是中广天泽',
#      'time_before': '03-20 12:35',
#      'truncated': False,
#      'truncatedBy': 0,
#      'user': {'allow_all_stock': False,
#       'block_status': 0,
#       'blocking': False,
#       'city': '',
#       'common_count': 0,
#       'description': '',
#       'donate_count': 0,
#       'follow_me': False,
#       'followers_count': 46,
#       'following': False,
#       'fortuneUser': False,
#       'friends_count': 79,
#       'gender': 'n',
#       'id': 2461599755,
#       'last_comment_id': 320108202,
#       'last_status_id': 282874124,
#       'photo_domain': 'http://xavatar.imedao.com/',
#       'profile': '/2461599755',
#       'profile_image_url': 'community/20233/1681685541965-1681685544259.jpg,community/20233/1681685541965-1681685544259.jpg!180x180.png,community/20233/1681685541965-1681685544259.jpg!50x50.png,community/20233/1681685541965-1681685544259.jpg!30x30.png',
#       'screen_name': '一只小小的太阳',
#       'st_color': '1',
#       'status': 0,
#       'status_count': 198,
#       'step': 'null',
#       'subscribeable': False,
#       'type': '1',
#       'user': {'allow_all_stock': False,
#        'anonymous': False,
#        'areaCode': '86',
#        'blocking': False,
#        'city': '',
#        'created_at': 1445694801170,
#        'description': '',
#        'donate_count': 0,
#        'donate_snowcoin': 0,
#        'follow_me': False,
#        'followers_count': 46,
#        'following': False,
#        'friends_count': 79,
#        'gender': 'n',
#        'id': 2461599755,
#        'last_comment_id': 320108202,
#        'last_status_id': 282874124,
#        'photo_domain': 'http://xavatar.imedao.com/',
#        'profile': '/2461599755',
#        'profile_image_url': 'community/20233/1681685541965-1681685544259.jpg,community/20233/1681685541965-1681685544259.jpg!180x180.png,community/20233/1681685541965-1681685544259.jpg!50x50.png,community/20233/1681685541965-1681685544259.jpg!30x30.png',
#        'screen_name': '一只小小的太阳',
#        'st_color': '1',
#        'status': 0,
#        'status_count': 198,
#        'step': 'null',
#        'truncated': False,
#        'type': '1',
#        'verified': False,
#        'verified_description': '',
#        'verified_type': 0},
#       'verified': False,
#       'verified_description': '',
#       'verified_realname': False,
#       'verified_type': 0},
#      'userId': 2461599755}],
#    'expend': True,
#    'fav_count': 50,
#    'favorited': False,
#    'flags': 36030068329284608,
#    'flagsObj': {'flags': 36030068329284608},
#    'hot': False,
#    'id': 282771985,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 31,
#    'liked': False,
#    'mark': 5,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 15,
#    'retweet_count': 1,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'Android',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/3119009799/282771985',
#    'text': '<p>华策影视：接入月之暗面大模型</p><p>海天瑞声：为kimi提供数据训练服务</p><p>掌阅科技：接入月之暗面kimi</p><p>中文在线：拥有可用于模型的IP数据</p><p>补充：</p><p>孩子王：预期接入kimi，kimi想要孩子王的育儿数据扩展大模型的to C应用端。</p><p>九安医疗：公司是砺思资本的有限合伙人，砺思资本参股了Kimi的母公司月之暗面。</p><p>中广天择：公司与Kimi智能助手的关联主要体现在公司为AI大模型提供数据支持和交易平台方面。</p><p><a href="http://xueqiu.com/S/SH603533" target="_blank">$掌阅科技(SH603533)$</a> <a href="http://xueqiu.com/S/SZ300133" target="_blank">$华策影视(SZ300133)$</a> <a href="http://xueqiu.com/S/SZ300364" target="_blank">$中文在线(SZ300364)$</a> </p>',
#    'timeBefore': '03-20 12:32',
#    'title': 'KIMI智能助手龙头股',
#    'trackJson': '{"fav_count":50,"created_at":1710909169000,"reply_count":15,"client_name":"Android","retweet_count":1,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '3',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '不限',
#     'common_count': 0,
#     'description': '日照澄洲江雾开，淘金女伴满江隈。 美人首饰侯王印，尽是沙中浪底来。（自己做股，莫跟随）',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 32581,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 245,
#     'gender': 'f',
#     'id': 3119009799,
#     'last_comment_id': 320366825,
#     'last_status_id': 283099333,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/3119009799',
#     'profile_image_url': 'community/20230/1673155317252-1673155317429.jpeg,community/20230/1673155317252-1673155317429.jpeg!180x180.png,community/20230/1673155317252-1673155317429.jpeg!50x50.png,community/20230/1673155317252-1673155317429.jpeg!30x30.png',
#     'province': '北京',
#     'screen_name': '顶底之王2024',
#     'st_color': '1',
#     'status': 2,
#     'status_count': 4129,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '不限',
#      'created_at': 1614424319515,
#      'description': '日照澄洲江雾开，淘金女伴满江隈。 美人首饰侯王印，尽是沙中浪底来。（自己做股，莫跟随）',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 32581,
#      'following': False,
#      'friends_count': 245,
#      'gender': 'f',
#      'id': 3119009799,
#      'last_comment_id': 320366825,
#      'last_status_id': 283099333,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/3119009799',
#      'profile_image_url': 'community/20230/1673155317252-1673155317429.jpeg,community/20230/1673155317252-1673155317429.jpeg!180x180.png,community/20230/1673155317252-1673155317429.jpeg!50x50.png,community/20230/1673155317252-1673155317429.jpeg!30x30.png',
#      'province': '北京',
#      'screen_name': '顶底之王2024',
#      'st_color': '1',
#      'status': 2,
#      'status_count': 4129,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#        'verified_type': '5'}],
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_infos': [{'verified_desc': '用户已完成实名身份认证', 'verified_type': '5'}],
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 3119009799,
#    'view_count': 122931},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1711071006000,
#    'description': '<a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a>加仓？减仓？要骰子，我选加<img src="http://js.xueqiu.com/ugc/images/face/emoji_73_gossip.png?v=1" title="[吃瓜]" alt="[吃瓜]" height="24" />',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'expend': False,
#    'fav_count': 0,
#    'favorited': False,
#    'flags': 1236950581248,
#    'flagsObj': {'flags': 1236950581248},
#    'hot': False,
#    'id': 283061218,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 2,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 17,
#    'retweet_count': 0,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'Android',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/1265127896/283061218',
#    'text': '<a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a>加仓？减仓？要骰子，我选加<img src="http://js.xueqiu.com/ugc/images/face/emoji_73_gossip.png?v=1" title="[吃瓜]" alt="[吃瓜]" height="24" />',
#    'timeBefore': '今天 09:30',
#    'title': '',
#    'trackJson': '{"fav_count":0,"created_at":1711071006000,"reply_count":17,"client_name":"Android","retweet_count":0,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '0',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '不限',
#     'common_count': 0,
#     'description': '天雨虽大，不润无根之草；道法虽宽，不渡无缘之人。',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 595,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 147,
#     'gender': 'm',
#     'id': 1265127896,
#     'last_comment_id': 320367400,
#     'last_status_id': 283100136,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/1265127896',
#     'profile_image_url': 'community/20241/1709010084044-1709010084221.jpeg,community/20241/1709010084044-1709010084221.jpeg!180x180.png,community/20241/1709010084044-1709010084221.jpeg!50x50.png,community/20241/1709010084044-1709010084221.jpeg!30x30.png',
#     'province': '其他',
#     'screen_name': '玄素双行',
#     'st_color': '1',
#     'status': 0,
#     'status_count': 1053,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '不限',
#      'created_at': 1564761385845,
#      'description': '天雨虽大，不润无根之草；道法虽宽，不渡无缘之人。',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 595,
#      'following': False,
#      'friends_count': 147,
#      'gender': 'm',
#      'id': 1265127896,
#      'last_comment_id': 320367400,
#      'last_status_id': 283100136,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/1265127896',
#      'profile_image_url': 'community/20241/1709010084044-1709010084221.jpeg,community/20241/1709010084044-1709010084221.jpeg!180x180.png,community/20241/1709010084044-1709010084221.jpeg!50x50.png,community/20241/1709010084044-1709010084221.jpeg!30x30.png',
#      'province': '其他',
#      'screen_name': '玄素双行',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 1053,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 1265127896,
#    'view_count': 10908},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1710993001000,
#    'description': '1.之江电影（东海）号称：中国编剧第一村。海量文库版权，出品方经常出现之江电影集团，影视剧经常爆火现象级别。<br/>2.浙文影业2024.3.14公告董事会和监事会换届，之江电影集团董事长傅立文一把手提名董事了，毫无疑问这就是新任董事长，老董事长没出现在新任董事会名单，监事沈力也是之江电影集...',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'expend': True,
#    'fav_count': 12,
#    'favorited': False,
#    'flags': 36028968817656832,
#    'flagsObj': {'flags': 36028968817656832},
#    'hot': False,
#    'id': 282933353,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 55,
#    'liked': False,
#    'mark': 5,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 0,
#    'retweet_count': 0,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'iPhone',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/1582210514/282933353',
#    'text': '<p>1.之江电影（东海）号称：中国编剧第一村。海量文库版权，出品方经常出现之江电影集团，影视剧经常爆火现象级别。<br/>2.浙文影业2024.3.14公告董事会和监事会换届，之江电影集团董事长傅立文一把手提名董事了，毫无疑问这就是新任董事长，老董事长没出现在新任董事会名单，监事沈力也是之江电影集团的董事二把手。之江电影集团工商也出现最新变更，法定代表人是徐晓钧（之前是之江电影总经理），以后之江电影集团就是浙文影业的旗下公司。还有冯薇薇之前是爱奇艺副总裁，此次聘任就是全面转型影视行业。<br/>3.浙文影业停牌在即，万事俱备，只欠东风，东风就是股东大会之后，今年停牌是大概率事件。</p><p><a href="http://xueqiu.com/S/SZ300133" target="_blank">$华策影视(SZ300133)$</a> <a href="http://xueqiu.com/S/SH603533" target="_blank">$掌阅科技(SH603533)$</a> <a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a> </p>',
#    'timeBefore': '03-21 11:50',
#    'title': '之江电影（东海）集团借壳浙文影业',
#    'trackJson': '{"fav_count":12,"created_at":1710993001000,"reply_count":0,"client_name":"iPhone","retweet_count":0,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '3',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '其他',
#     'common_count': 0,
#     'description': '全网都叫超级大题材',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 12281,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 1,
#     'id': 1582210514,
#     'last_comment_id': 320296990,
#     'last_status_id': 282933353,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/1582210514',
#     'profile_image_url': 'community/20231/1677258210128-1677258211037.jpg,community/20231/1677258210128-1677258211037.jpg!180x180.png,community/20231/1677258210128-1677258211037.jpg!50x50.png,community/20231/1677258210128-1677258211037.jpg!30x30.png',
#     'province': '海外',
#     'screen_name': '超级大题材',
#     'st_color': '1',
#     'status': 0,
#     'status_count': 146,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '其他',
#      'created_at': 1581818029830,
#      'description': '全网都叫超级大题材',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 12281,
#      'following': False,
#      'friends_count': 1,
#      'id': 1582210514,
#      'last_comment_id': 320296990,
#      'last_status_id': 282933353,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/1582210514',
#      'profile_image_url': 'community/20231/1677258210128-1677258211037.jpg,community/20231/1677258210128-1677258211037.jpg!180x180.png,community/20231/1677258210128-1677258211037.jpg!50x50.png,community/20231/1677258210128-1677258211037.jpg!30x30.png',
#      'province': '海外',
#      'screen_name': '超级大题材',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 146,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#        'verified_type': '5'}],
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_infos': [{'verified_desc': '用户已完成实名身份认证', 'verified_type': '5'}],
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 1582210514,
#    'view_count': 57562},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1710911515000,
#    'description': '【Kimi概念股持续走强 海天瑞声20CM涨停】海天瑞声20CM涨停，华策影视、掌阅科技、中广天择涨停，九安医疗、深信服跟涨。消息面上，近日月之暗面宣布其对话式AI助手产品Kimi智能助手现已支持200万字的无损上下文输入。',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'excellent_comments': [{'blocked': False,
#      'blocking': False,
#      'canEdit': True,
#      'censored': False,
#      'client': 'JtXbaMn7eP',
#      'createdAt': 1710916129000,
#      'description': '好了，现在全市场都知道百度的大模型比不上月之暗面moonshot了<img src="http://js.xueqiu.com/ugc/images/face/emoji_07_wonderful.png?v=1" title="[牛]" alt="[牛]" height="24" />',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'donate_user_count': 0,
#      'id': 320124239,
#      'inReplyToCommentId': 0,
#      'indexText': '好了，现在全市场都知道百度的大模型比不上月之暗面moonshot了 ',
#      'likeCount': 13,
#      'originalText': '好了，现在全市场都知道百度的大模型比不上月之暗面moonshot了<img src="http://js.xueqiu.com/ugc/images/face/emoji_07_wonderful.png?v=1" title="[牛]" alt="[牛]" height="24" />',
#      'pic': '',
#      'picSizes': [],
#      'reply_remark': '',
#      'reply_screenName': '',
#      'reply_verified': False,
#      'reply_verified_description': '',
#      'rootInReplyToStatusId': 282777101,
#      'source': '股票微博',
#      'source_view': '雪球',
#      'statusId': 0,
#      'text': '好了，现在全市场都知道百度的大模型比不上月之暗面moonshot了<img src="http://js.xueqiu.com/ugc/images/face/emoji_07_wonderful.png?v=1" title="[牛]" alt="[牛]" height="24" />',
#      'time_before': '03-20 14:28',
#      'truncated': False,
#      'truncatedBy': 0,
#      'user': {'allow_all_stock': False,
#       'block_status': 0,
#       'blocking': False,
#       'city': '不限',
#       'common_count': 0,
#       'description': '',
#       'donate_count': 0,
#       'follow_me': False,
#       'followers_count': 346,
#       'following': False,
#       'fortuneUser': False,
#       'friends_count': 57,
#       'gender': 'm',
#       'id': 2896313750,
#       'last_comment_id': 320254852,
#       'last_status_id': 283094514,
#       'photo_domain': 'http://xavatar.imedao.com/',
#       'profile': '/2896313750',
#       'profile_image_url': 'community/20216/1627395917111-1627395917208.jpeg,community/20216/1627395917111-1627395917208.jpeg!180x180.png,community/20216/1627395917111-1627395917208.jpeg!50x50.png,community/20216/1627395917111-1627395917208.jpeg!30x30.png',
#       'province': '不限',
#       'screen_name': '现在买房被坑一辈子',
#       'st_color': '1',
#       'status': 0,
#       'status_count': 4,
#       'step': 'two',
#       'subscribeable': False,
#       'type': '1',
#       'user': {'allow_all_stock': False,
#        'anonymous': False,
#        'areaCode': '86',
#        'blocking': False,
#        'city': '不限',
#        'created_at': 1463712991871,
#        'description': '',
#        'donate_count': 0,
#        'donate_snowcoin': 0,
#        'follow_me': False,
#        'followers_count': 346,
#        'following': False,
#        'friends_count': 57,
#        'gender': 'm',
#        'id': 2896313750,
#        'last_comment_id': 320254852,
#        'last_status_id': 283094514,
#        'photo_domain': 'http://xavatar.imedao.com/',
#        'profile': '/2896313750',
#        'profile_image_url': 'community/20216/1627395917111-1627395917208.jpeg,community/20216/1627395917111-1627395917208.jpeg!180x180.png,community/20216/1627395917111-1627395917208.jpeg!50x50.png,community/20216/1627395917111-1627395917208.jpeg!30x30.png',
#        'province': '不限',
#        'screen_name': '现在买房被坑一辈子',
#        'st_color': '1',
#        'status': 0,
#        'status_count': 4,
#        'step': 'two',
#        'truncated': False,
#        'type': '1',
#        'verified': False,
#        'verified_description': '',
#        'verified_type': 0},
#       'verified': False,
#       'verified_description': '',
#       'verified_realname': False,
#       'verified_type': 0},
#      'userId': 2896313750}],
#    'expend': False,
#    'fav_count': 19,
#    'favorited': False,
#    'flags': 36030033969545216,
#    'flagsObj': {'flags': 36030033969545216},
#    'hot': False,
#    'id': 282777101,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 23,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 22,
#    'retweet_count': 5,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': '雪球',
#    'source_feed': False,
#    'target': '/5124430882/282777101',
#    'text': '【Kimi概念股持续走强 海天瑞声20CM涨停】海天瑞声20CM涨停，华策影视、掌阅科技、中广天择涨停，九安医疗、深信服跟涨。消息面上，近日月之暗面宣布其对话式AI助手产品Kimi智能助手现已支持200万字的无损上下文输入。',
#    'timeBefore': '03-20 13:11',
#    'title': '',
#    'trackJson': '{"fav_count":19,"created_at":1710911515000,"reply_count":22,"client_name":"","retweet_count":5,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '0',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '不限',
#     'common_count': 0,
#     'description': '',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 519200,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 0,
#     'gender': 'n',
#     'id': 5124430882,
#     'last_comment_id': 319828158,
#     'last_status_id': 283100696,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/5124430882',
#     'profile_image_url': 'community/20229/1665999720756-1665999720902.png,community/20229/1665999720756-1665999720902.png!180x180.png,community/20229/1665999720756-1665999720902.png!50x50.png,community/20229/1665999720756-1665999720902.png!30x30.png',
#     'province': '北京',
#     'screen_name': '7X24快讯',
#     'st_color': '1',
#     'status': 1,
#     'status_count': 987119,
#     'step': 'three',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'ability': '乐视网,卓能(集团),申万宏源',
#      'allow_all_stock': False,
#      'anonymous': False,
#      'blocking': False,
#      'city': '不限',
#      'created_at': 1453197883068,
#      'description': '',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 519200,
#      'following': False,
#      'friends_count': 0,
#      'gender': 'n',
#      'id': 5124430882,
#      'last_comment_id': 319828158,
#      'last_status_id': 283100696,
#      'maskedEmail': 'wan***@xueqiu.com',
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/5124430882',
#      'profile_image_url': 'community/20229/1665999720756-1665999720902.png,community/20229/1665999720756-1665999720902.png!180x180.png,community/20229/1665999720756-1665999720902.png!50x50.png,community/20229/1665999720756-1665999720902.png!30x30.png',
#      'province': '北京',
#      'screen_name': '7X24快讯',
#      'st_color': '1',
#      'status': 1,
#      'status_count': 987119,
#      'step': 'three',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 5124430882,
#    'view_count': 64991},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1710814162000,
#    'description': '第一个半小时，指数低开高走，游戏传媒TMT大涨，万兴、昆仑、天娱、贝士达克我都开始高抛，中广天择已经没有了。原则是今天大量减仓，先拉升的先止盈，大肉的先落袋。<br/>量能上同比昨日开始缩量，目前是三百亿。只要全天缩量不超过千亿，那么今天依然可以维持万亿成交，方便我跑路。盘面上半小时...',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'expend': True,
#    'fav_count': 0,
#    'favorited': False,
#    'flags': 36030033969545216,
#    'flagsObj': {'flags': 36030033969545216},
#    'hot': False,
#    'id': 282585314,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 17,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 35,
#    'retweet_count': 0,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'iPhone',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/1071814723/282585314',
#    'text': '第一个半小时，指数低开高走，游戏传媒TMT大涨，万兴、昆仑、天娱、贝士达克我都开始高抛，中广天择已经没有了。原则是今天大量减仓，先拉升的先止盈，大肉的先落袋。<br/>量能上同比昨日开始缩量，目前是三百亿。只要全天缩量不超过千亿，那么今天依然可以维持万亿成交，方便我跑路。盘面上半小时涨停板就已经达到42家，资金依然非常活跃，煤飞色舞、肉类、AI此起彼伏。从2600拉起来的这四百多点，资金吃饱后有序撤离也不是一朝一夕的事情。<a href="http://xueqiu.com/S/SZ002085" target="_blank">$万丰奥威(SZ002085)$</a> <a href="http://xueqiu.com/S/SH603259" target="_blank">$药明康德(SH603259)$</a> <a href="http://xueqiu.com/S/SH600006" target="_blank">$东风汽车(SH600006)$</a>',
#    'timeBefore': '03-19 10:09',
#    'title': '',
# ...
#    'donate_snowcoin': 0,
#    'editable': True,
#    'expend': True,
#    'fav_count': 0,
#    'favorited': False,
#    'flags': 36030033969545216,
#    'flagsObj': {'flags': 36030033969545216},
#    'hot': False,
#    'id': 282756266,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 3,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 24,
#    'retweet_count': 0,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'Android',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/8188596892/282756266',
#    'text': '指数如果强的话<br/>传媒应用端是有条件爆的<br/>几个点<br/>泛Ai方向cpo新高，液冷新高，<br/>算力新高<br/>那业绩最先落地的应用端，怎么都要出些新高<br/>而且板块联动其实挺强的<br/>掌阅科技高开秒板<br/>中广天择反包涨停<br/>引力传媒1+1<br/>因赛集团反包<br/><a href="http://xueqiu.com/S/SH603327" target="_blank">$福蓉科技(SH603327)$</a> <a href="http://xueqiu.com/S/SZ000628" target="_blank">$高新发展(SZ000628)$</a> <a href="http://xueqiu.com/S/SZ002085" target="_blank">$万丰奥威(SZ002085)$</a> <a href="http://xueqiu.com/k?q=%23%E9%93%9C%E7%BC%86%E9%AB%98%E9%80%9F%E8%BF%9E%E6%8E%A5%E5%99%A8%E9%9B%86%E4%BD%93%E9%AB%98%E5%BC%80%EF%BC%8C%E5%85%86%E9%BE%99%E4%BA%92%E8%BF%9E%E5%A4%A7%E6%B6%A8%23" target="_blank">#铜缆高速连接器集体高开，兆龙互连大涨#</a> <a href="http://xueqiu.com/k?q=%23%E4%BC%A0%E5%AA%92%E7%BB%A7%E7%BB%AD%E7%8B%82%E9%A3%99%EF%BC%81AI%E5%BA%94%E7%94%A8%E8%BF%98%E8%83%BD%E7%82%92%E5%A4%9A%E4%B9%85%23" target="_blank">#传媒继续狂飙！AI应用还能炒多久#</a>',
#    'timeBefore': '03-20 11:01',
#    'title': '',
#    'trackJson': '{"fav_count":0,"created_at":1710903716000,"reply_count":24,"client_name":"Android","retweet_count":0,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '0',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '未知',
#     'common_count': 0,
#     'description': '',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 1230,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 27,
#     'gender': 'n',
#     'id': 8188596892,
#     'last_comment_id': 320367563,
#     'last_status_id': 283098569,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/8188596892',
#     'profile_image_url': 'community/202310/1700318663834-1700318664038.jpeg,community/202310/1700318663834-1700318664038.jpeg!180x180.png,community/202310/1700318663834-1700318664038.jpeg!50x50.png,community/202310/1700318663834-1700318664038.jpeg!30x30.png',
#     'province': '不限',
#     'screen_name': '只会炒鸡蛋',
#     'st_color': '1',
#     'status': 0,
#     'status_count': 1854,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '未知',
#      'created_at': 1666341774318,
#      'description': '',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 1230,
#      'following': False,
#      'friends_count': 27,
#      'gender': 'n',
#      'id': 8188596892,
#      'last_comment_id': 320367563,
#      'last_status_id': 283098569,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/8188596892',
#      'profile_image_url': 'community/202310/1700318663834-1700318664038.jpeg,community/202310/1700318663834-1700318664038.jpeg!180x180.png,community/202310/1700318663834-1700318664038.jpeg!50x50.png,community/202310/1700318663834-1700318664038.jpeg!30x30.png',
#      'province': '不限',
#      'screen_name': '只会炒鸡蛋',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 1854,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 8188596892,
#    'view_count': 15808},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1709877589000,
#    'description': '<a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a> 搞点文生视频概念',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'excellent_comments': [{'blocked': False,
#      'blocking': False,
#      'canEdit': True,
#      'censored': False,
#      'client': 'JtXbaMn7eP',
#      'createdAt': 1710299612000,
#      'description': '哈哈，又起飞了一个，舒服<img src="http://js.xueqiu.com/ugc/images/face/emoji_83_rocket.png?v=1" title="[火箭]" alt="[火箭]" height="24" /><a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a>',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'donate_user_count': 0,
#      'id': 319335543,
#      'inReplyToCommentId': 0,
#      'indexText': '哈哈，又起飞了一个，舒服  $中广天择(SH603721)$ ',
#      'likeCount': 19,
#      'originalText': '哈哈，又起飞了一个，舒服<img src="http://js.xueqiu.com/ugc/images/face/emoji_83_rocket.png?v=1" title="[火箭]" alt="[火箭]" height="24" /><a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a>',
#      'pic': '',
#      'picSizes': [],
#      'reply_remark': '',
#      'reply_screenName': '',
#      'reply_verified': False,
#      'reply_verified_description': '',
#      'rootInReplyToStatusId': 281290367,
#      'source': '股票微博',
#      'source_view': '雪球',
#      'statusId': 281845502,
#      'text': '哈哈，又起飞了一个，舒服<img src="http://js.xueqiu.com/ugc/images/face/emoji_83_rocket.png?v=1" title="[火箭]" alt="[火箭]" height="24" /><a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a>',
#      'time_before': '03-13 11:13',
#      'truncated': False,
#      'truncatedBy': 0,
#      'user': {'allow_all_stock': False,
#       'block_status': 0,
#       'blocking': False,
#       'city': '不限',
#       'common_count': 0,
#       'description': '精通缠论，擅长技术面分析抓取主升浪票，不接私信，打赏必回关',
#       'donate_count': 0,
#       'follow_me': False,
#       'followers_count': 10341,
#       'following': False,
#       'fortuneUser': False,
#       'friends_count': 1141,
#       'gender': 'n',
#       'id': 7078444120,
#       'last_comment_id': 320355710,
#       'last_status_id': 283086471,
#       'photo_domain': 'http://xavatar.imedao.com/',
#       'profile': '/7078444120',
#       'profile_image_url': 'community/20240/1705581322579-1705581323220.jpeg,community/20240/1705581322579-1705581323220.jpeg!180x180.png,community/20240/1705581322579-1705581323220.jpeg!50x50.png,community/20240/1705581322579-1705581323220.jpeg!30x30.png',
#       'province': '海外',
#       'screen_name': '缠论主升浪',
#       'st_color': '1',
#       'status': 0,
#       'status_count': 4010,
#       'step': 'null',
#       'subscribeable': False,
#       'type': '1',
#       'user': {'allow_all_stock': False,
#        'anonymous': False,
#        'areaCode': '86',
#        'blocking': False,
#        'city': '不限',
#        'created_at': 1477576491544,
#        'description': '精通缠论，擅长技术面分析抓取主升浪票，不接私信，打赏必回关',
#        'donate_count': 0,
#        'donate_snowcoin': 0,
#        'follow_me': False,
#        'followers_count': 10341,
#        'following': False,
#        'friends_count': 1141,
#        'gender': 'n',
#        'id': 7078444120,
#        'last_comment_id': 320355710,
#        'last_status_id': 283086471,
#        'photo_domain': 'http://xavatar.imedao.com/',
#        'profile': '/7078444120',
#        'profile_image_url': 'community/20240/1705581322579-1705581323220.jpeg,community/20240/1705581322579-1705581323220.jpeg!180x180.png,community/20240/1705581322579-1705581323220.jpeg!50x50.png,community/20240/1705581322579-1705581323220.jpeg!30x30.png',
#        'province': '海外',
#        'screen_name': '缠论主升浪',
#        'st_color': '1',
#        'status': 0,
#        'status_count': 4010,
#        'step': 'null',
#        'truncated': False,
#        'type': '1',
#        'verified': False,
#        'verified_description': '',
#        'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#          'verified_type': '5'}],
#        'verified_type': 0},
#       'verified': False,
#       'verified_description': '',
#       'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#         'verified_type': '5'}],
#       'verified_realname': False,
#       'verified_type': 0},
#      'userId': 7078444120}],
#    'expend': True,
#    'fav_count': 0,
#    'favorited': False,
#    'firstImg': 'https://xqimg.imedao.com/18e1ca56d2445a1d3fbd540d.jpeg!thumb.jpg',
#    'flags': 137438953472,
#    'flagsObj': {'flags': 137438953472},
#    'hot': False,
#    'id': 281290367,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 12,
#    'liked': False,
#    'mark': 0,
#    'pic': 'https://xqimg.imedao.com/18e1ca56d2445a1d3fbd540d.jpeg!thumb.jpg',
#    'pic_sizes': [{'height': 1578,
#      'ratio': '0.83',
#      'score': 0,
#      'setHeight': True,
#      'setRatio': True,
#      'setScore': True,
#      'setWidth': True,
#      'width': 1312}],
#    'promotion_id': 0,
#    'reply_count': 31,
#    'retweet_count': 8,
#    'retweet_status_id': 0,
#    'reward_count': 1,
#    'reward_user_count': 1,
#    'rqid': 0,
#    'source': 'Android',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/7078444120/281290367',
#    'text': '<a href="http://xueqiu.com/S/SH603721" target="_blank">$中广天择(SH603721)$</a> 搞点文生视频概念<br/><img class="ke_img" src="https://xqimg.imedao.com/18e1ca56d2445a1d3fbd540d.jpeg!custom.jpg" />',
#    'timeBefore': '03-08 13:59',
#    'title': '',
#    'trackJson': '{"fav_count":0,"created_at":1709877589000,"reply_count":31,"client_name":"Android","retweet_count":8,"reward_count":1}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '0',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '不限',
#     'common_count': 0,
#     'description': '精通缠论，擅长技术面分析抓取主升浪票，不接私信，打赏必回关',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 10341,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 1141,
#     'gender': 'n',
#     'id': 7078444120,
#     'last_comment_id': 320355710,
#     'last_status_id': 283086471,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/7078444120',
#     'profile_image_url': 'community/20240/1705581322579-1705581323220.jpeg,community/20240/1705581322579-1705581323220.jpeg!180x180.png,community/20240/1705581322579-1705581323220.jpeg!50x50.png,community/20240/1705581322579-1705581323220.jpeg!30x30.png',
#     'province': '海外',
#     'screen_name': '缠论主升浪',
#     'st_color': '1',
#     'status': 0,
#     'status_count': 4010,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '不限',
#      'created_at': 1477576491544,
#      'description': '精通缠论，擅长技术面分析抓取主升浪票，不接私信，打赏必回关',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 10341,
#      'following': False,
#      'friends_count': 1141,
#      'gender': 'n',
#      'id': 7078444120,
#      'last_comment_id': 320355710,
#      'last_status_id': 283086471,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/7078444120',
#      'profile_image_url': 'community/20240/1705581322579-1705581323220.jpeg,community/20240/1705581322579-1705581323220.jpeg!180x180.png,community/20240/1705581322579-1705581323220.jpeg!50x50.png,community/20240/1705581322579-1705581323220.jpeg!30x30.png',
#      'province': '海外',
#      'screen_name': '缠论主升浪',
#      'st_color': '1',
#      'status': 0,
#      'status_count': 4010,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#        'verified_type': '5'}],
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_infos': [{'verified_desc': '用户已完成实名身份认证', 'verified_type': '5'}],
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 7078444120,
#    'view_count': 45875},
#   {'blocked': False,
#    'blocking': False,
#    'canEdit': True,
#    'commentId': 0,
#    'controversial': False,
#    'created_at': 1711022271000,
#    'description': '<a href="http://xueqiu.com/S/SH603580" target="_blank">$艾艾精工(SH603580)$</a><br/>明天重点关注板块及个股:<br/>①低空经济:永悦科技（龙头）、北纬科技、东方时尚、四创电子。<br/>②传媒（kimi）:掌阅科技、中广天择、浙文互联。',
#    'donate_count': 0,
#    'donate_snowcoin': 0,
#    'editable': True,
#    'expend': False,
#    'fav_count': 2,
#    'favorited': False,
#    'flags': 36030033969545216,
#    'flagsObj': {'flags': 36030033969545216},
#    'hot': False,
#    'id': 283007138,
#    'is_answer': False,
#    'is_bonus': False,
#    'is_refused': False,
#    'is_reward': True,
#    'is_ss_multi_pic': False,
#    'legal_user_visible': False,
#    'like_count': 3,
#    'liked': False,
#    'mark': 0,
#    'pic': '',
#    'promotion_id': 0,
#    'reply_count': 5,
#    'retweet_count': 0,
#    'retweet_status_id': 0,
#    'reward_count': 0,
#    'reward_user_count': 0,
#    'rqid': 0,
#    'source': 'Android',
#    'source_feed': False,
#    'source_link': 'http://xueqiu.com/about/mobile-xueqiu',
#    'target': '/2648207902/283007138',
#    'text': '<a href="http://xueqiu.com/S/SH603580" target="_blank">$艾艾精工(SH603580)$</a><br/>明天重点关注板块及个股:<br/>①低空经济:永悦科技（龙头）、北纬科技、东方时尚、四创电子。<br/>②传媒（kimi）:掌阅科技、中广天择、浙文互联。',
#    'timeBefore': '03-21 19:57',
#    'title': '',
#    'trackJson': '{"fav_count":2,"created_at":1711022271000,"reply_count":5,"client_name":"Android","retweet_count":0,"reward_count":0}',
#    'truncated': False,
#    'truncated_by': 0,
#    'type': '0',
#    'user': {'allow_all_stock': False,
#     'block_status': 0,
#     'blocking': False,
#     'city': '苏州',
#     'common_count': 0,
#     'description': '详细复盘关注️WX:财神已到。',
#     'donate_count': 0,
#     'follow_me': False,
#     'followers_count': 1114,
#     'following': False,
#     'fortuneUser': False,
#     'friends_count': 0,
#     'gender': 'm',
#     'id': 2648207902,
#     'last_comment_id': 320324287,
#     'last_status_id': 283007138,
#     'photo_domain': 'http://xavatar.imedao.com/',
#     'profile': '/2648207902',
#     'profile_image_url': 'community/20241/1707894211578-1707894211754.jpeg,community/20241/1707894211578-1707894211754.jpeg!180x180.png,community/20241/1707894211578-1707894211754.jpeg!50x50.png,community/20241/1707894211578-1707894211754.jpeg!30x30.png',
#     'province': '江苏',
#     'screen_name': '财神已到',
#     'st_color': '1',
#     'status': 2,
#     'status_count': 228,
#     'step': 'null',
#     'subscribeable': False,
#     'type': '1',
#     'user': {'allow_all_stock': False,
#      'anonymous': False,
#      'areaCode': '86',
#      'blocking': False,
#      'city': '苏州',
#      'created_at': 1682613879897,
#      'description': '详细复盘关注️WX:财神已到。',
#      'donate_count': 0,
#      'donate_snowcoin': 0,
#      'follow_me': False,
#      'followers_count': 1114,
#      'following': False,
#      'friends_count': 0,
#      'gender': 'm',
#      'id': 2648207902,
#      'last_comment_id': 320324287,
#      'last_status_id': 283007138,
#      'photo_domain': 'http://xavatar.imedao.com/',
#      'profile': '/2648207902',
#      'profile_image_url': 'community/20241/1707894211578-1707894211754.jpeg,community/20241/1707894211578-1707894211754.jpeg!180x180.png,community/20241/1707894211578-1707894211754.jpeg!50x50.png,community/20241/1707894211578-1707894211754.jpeg!30x30.png',
#      'province': '江苏',
#      'screen_name': '财神已到',
#      'st_color': '1',
#      'status': 2,
#      'status_count': 228,
#      'step': 'null',
#      'truncated': False,
#      'type': '1',
#      'verified': False,
#      'verified_description': '',
#      'verified_infos': [{'verified_desc': '用户已完成实名身份认证',
#        'verified_type': '5'}],
#      'verified_type': 0},
#     'verified': False,
#     'verified_description': '',
#     'verified_infos': [{'verified_desc': '用户已完成实名身份认证', 'verified_type': '5'}],
#     'verified_realname': False,
#     'verified_type': 0},
#    'user_id': 2648207902,
#    'view_count': 11975}],
#  'maxPage': 100,
#  'page': 1,
#  'q': 'SH603721',
#  'query_id': 1771021506625888256,
#  'recommend_cards': []}

# %% [markdown]
# response['list']是主要的内容
#
#     response['list']: controversial, created_at, ['excellent_comments'], fav_count, hot, id, like_count, offer, is_answer, is_bonus, is_refused, is_reward, ['pic_sizes'], reply_count, retweet_count, reward_count, reward_user_count, title, user, retweet_status_id, retweet_status, text
#
#         ['excellent_comments']: createdAt, id, inReplyToCommentId, indexText, likeCount, pic, picSizes, user
#
#             user: common_count, description, followers_count粉丝, friend_count关注, gender, id, screen_name用户名, user, city
#
#                 user: created_at,
#
#     offer: amount, balance, dueTime, id
#
#     user: corpName, description, donate_count, followers_count, friends_count, gender, id, province, screen_name, user, gender, verified, user_id, view_count
#
#         user: created_at

# %%
len(test['list'])
# Out:
# 20

# %%
test1 = fetch_data(symbol='SH603721', page=49)

# %%
import sys

def get_size(obj, seen=None):
    """递归地计算对象及其所引用的内容的总内存占用大小"""
    size = sys.getsizeof(obj)
    if seen is None:
        seen = set()
    obj_id = id(obj)
    if obj_id in seen:
        return 0
    seen.add(obj_id)
    if isinstance(obj, dict):
        size += sum([get_size(v, seen) for v in obj.values()])
        size += sum([get_size(k, seen) for k in obj.keys()])
    elif hasattr(obj, '__dict__'):
        size += get_size(obj.__dict__, seen)
    elif hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):
        size += sum([get_size(i, seen) for i in obj])
    return size
