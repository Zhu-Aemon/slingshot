# %% [markdown]
# 龙虎榜url ifind

# %%
import pandas as pd
import requests

def get_lhb_stock_data():
    url = 'http://data.10jqka.com.cn/api/lhbstockdate/code/300343/callback/jsonp_callback_lhbstockdate'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36',
        'Accept': '*/*',
        'Accept-Encoding': 'gzip, deflate',
        'Accept-Language': 'zh-CN,zh;q=0.9,zh-TW;q=0.8,en;q=0.7',
        'Referer': 'http://vis-free.10jqka.com.cn/billboard/ifind/html/index.html?theme=newgrey'
    }
    cookies = {
        'sessionid': '15358e32dfe6a519f28ededa1f21d8d22',
        'jgbsessid': '8c16101ce87ac72c4790f7b2bc159d1e',
        'THSFT_USERID': 'zyzq3602',
        'u_name': 'zyzq3602',
        'userid': '682593258',
        'user': 'Onp5enEzNjAyOjo6Ojo1NCwxMTAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDA'
    }
    response = requests.get(url, headers=headers, cookies=cookies)
    
    if response.status_code == 200:
        return response

# 调用函数并打印结果
result = get_lhb_stock_data()
result.text
# Out:
# 'jsonp_callback_lhbstockdate({"data":[{"date":"2024-03-26","type":1,"reason":"\\u6709\\u4ef7\\u683c\\u6da8\\u8dcc\\u5e45\\u9650\\u5236\\u7684\\u65e5\\u6536\\u76d8\\u4ef7\\u683c\\u6da8\\u5e45\\u8fbe\\u523015%\\u7684\\u8bc1\\u5238"},{"date":"2024-02-08","type":1,"reason":"\\u6709\\u4ef7\\u683c\\u6da8\\u8dcc\\u5e45\\u9650\\u5236\\u7684\\u65e5\\u6536\\u76d8\\u4ef7\\u683c\\u6da8\\u5e45\\u8fbe\\u523015%\\u7684\\u8bc1\\u5238"},{"date":"2023-07-10","type":1,"reason":"\\u6709\\u4ef7\\u683c\\u6da8\\u8dcc\\u5e45\\u9650\\u5236\\u7684\\u65e5\\u6536\\u76d8\\u4ef7\\u683c\\u6da8\\u5e45\\u8fbe\\u523015%\\u7684\\u8bc1\\u5238"}],"status_code":0,"status_msg":"success"})'

# %%
eval(result.text.lstrip('jsonp_callback_lhbstockdate(').rstrip(')'))
# Out:
# {'data': [{'date': '2024-03-26',
#    'type': 1,
#    'reason': '有价格涨跌幅限制的日收盘价格涨幅达到15%的证券'},
#   {'date': '2024-02-08', 'type': 1, 'reason': '有价格涨跌幅限制的日收盘价格涨幅达到15%的证券'},
#   {'date': '2023-07-10', 'type': 1, 'reason': '有价格涨跌幅限制的日收盘价格涨幅达到15%的证券'}],
#  'status_code': 0,
#  'status_msg': 'success'}

# %%
import requests

def get_data():
    url = "http://data.10jqka.com.cn/api/lhclientdate/date/2024-03-26/code/603721/reason/"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "zh-CN,zh;q=0.9,zh-TW;q=0.8,en;q=0.7",
        "Connection": "close",
        "Cookie": "sessionid=15358e32dfe6a519f28ededa1f21d8d22; jgbsessid=8c16101ce87ac72c4790f7b2bc159d1e; THSFT_USERID=zyzq3602; u_name=zyzq3602; userid=682593258; user=Onp5enEzNjAyOjo6Ojo1NCwxMTAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDA",
        "Referer": "http://vis-free.10jqka.com.cn/billboard/ifind/html/index.html?theme=newgrey"
    }
    
    try:
        response = requests.get(url, headers=headers)
        return response
    except requests.exceptions.RequestException as e:
        print("Error:", e)
        return None

# 示例用法
data = get_data()
data.text
# Out:
# '{"data":{"analysis":[{"type":"\\u65e5\\u632f\\u5e45\\u503c\\u8fbe15%\\u7684\\u8bc1\\u5238\\uff1b\\u65e5\\u6362\\u624b\\u7387\\u8fbe20%\\u7684\\u8bc1\\u5238","buy":[{"yyb":"\\u4e2d\\u4fe1\\u5efa\\u6295\\u5317\\u4eac\\u4e2d\\u4fe1\\u5927\\u53a6","yybqc":"\\u4e2d\\u4fe1\\u5efa\\u6295\\u8bc1\\u5238\\u80a1\\u4efd\\u6709\\u9650\\u516c\\u53f8\\u5317\\u4eac\\u4e2d\\u4fe1\\u5927\\u53a6\\u8bc1\\u5238\\u8425\\u4e1a\\u90e8","yybid":"dd760525a4858949","source_yyb_id":"dd760525a4858949","holdnum":"7128.59","money":"71285900","buy":"71285900","sell":"0","tag":"","tagid":"","cb":"37.76","amount":"1888100","last_tag":""},{"yyb":"\\u5357\\u4eac\\u8bc1\\u5238\\u7ecd\\u5174\\u4eba\\u6c11\\u4e1c\\u8def","yybqc":"\\u5357\\u4eac\\u8bc1\\u5238\\u80a1\\u4efd\\u6709\\u9650\\u516c\\u53f8\\u7ecd\\u5174\\u4eba\\u6c11\\u4e1c\\u8def\\u8bc1\\u5238\\u8425\\u4e1a\\u90e8","yybid":"d76b9d20c486cb72","source_yyb_id":"d76b9d20c486cb72","holdnum":"3685.20","money":"36852000","buy":"36852000","sell":"0","tag":"","tagid":"
# ...

# %%
data.json()
# Out:
# {'data': {'analysis': [{'type': '日振幅值达15%的证券；日换手率达20%的证券',
#     'buy': [{'yyb': '中信建投北京中信大厦',
#       'yybqc': '中信建投证券股份有限公司北京中信大厦证券营业部',
#       'yybid': 'dd760525a4858949',
#       'source_yyb_id': 'dd760525a4858949',
#       'holdnum': '7128.59',
#       'money': '71285900',
#       'buy': '71285900',
#       'sell': '0',
#       'tag': '',
#       'tagid': '',
#       'cb': '37.76',
#       'amount': '1888100',
#       'last_tag': ''},
#      {'yyb': '南京证券绍兴人民东路',
#       'yybqc': '南京证券股份有限公司绍兴人民东路证券营业部',
#       'yybid': 'd76b9d20c486cb72',
#       'source_yyb_id': 'd76b9d20c486cb72',
#       'holdnum': '3685.20',
#       'money': '36852000',
#       'buy': '36852000',
#       'sell': '0',
#       'tag': '',
#       'tagid': '',
#       'cb': '37.36',
#       'amount': '986400',
#       'last_tag': ''},
#      {'yyb': '机构专用',
#       'yybqc': '机构专用',
#       'yybid': 'JGZY_1_1_3',
#       'source_yyb_id': 'JGZY',
#       'holdnum': '5121.50',
#       'money': '20067900',
# ...

# %% [markdown]
# 获取交易日历

# %%
import requests

def send_http_request():
    url = "http://dsfwt.10jqka.com.cn/bidding/api/tradingday/startdate/20230326/"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36",
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "zh-CN,zh;q=0.9,zh-TW;q=0.8,en;q=0.7",
        "Connection": "close",
        "Content-Type": "application/x-www-form-urlencoded;charset=UTF-8",
        "Cookie": "sessionid=15358e32dfe6a519f28ededa1f21d8d22; jgbsessid=8c16101ce87ac72c4790f7b2bc159d1e; THSFT_USERID=zyzq3602; u_name=zyzq3602; userid=682593258; user=Onp5enEzNjAyOjo6Ojo1NCwxMTAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDA",
        "Referer": "http://vis-free.10jqka.com.cn/billboard/ifind/html/index.html?theme=newgrey"
    }
    
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        print("请求成功")
        return response
    else:
        print("请求失败")

# 调用函数发送请求
test = send_http_request()
test.text
# Out:
# 请求成功
# ...

# %%
test.json()['data']
# Out:
# ['20230327',
#  '20230328',
#  '20230329',
#  '20230330',
#  '20230331',
#  '20230403',
#  '20230404',
#  '20230406',
#  '20230407',
#  '20230410',
#  '20230411',
#  '20230412',
#  '20230413',
#  '20230414',
#  '20230417',
#  '20230418',
#  '20230419',
#  '20230420',
#  '20230421',
#  '20230424',
#  '20230425',
#  '20230426',
#  '20230427',
#  '20230428',
#  '20230504',
#  '20230505',
#  '20230508',
#  '20230509',
#  '20230510',
#  '20230511',
#  '20230512',
#  '20230515',
#  '20230516',
#  '20230517',
#  '20230518',
#  '20230519',
#  '20230522',
#  '20230523',
#  '20230524',
#  '20230525',
#  '20230526',
#  '20230529',
#  '20230530',
#  '20230531',
#  '20230601',
#  '20230602',
#  '20230605',
#  '20230606',
#  '20230607',
#  '20230608',
#  '20230609',
#  '20230612',
#  '20230613',
#  '20230614',
#  '20230615',
#  '20230616',
#  '20230619',
#  '20230620',
#  '20230621',
#  '20230626',
#  '20230627',
#  '20230628',
#  '20230629',
#  '20230630',
#  '20230703',
#  '20230704',
# ...

# %% [markdown]
# 获取估值
#
# Hypertext Transfer Protocol
#     GET /thsft/iFindService/StockHq/index/picturedata?&entry=gz&hqcode=603722&enddate=20240326&items=169 HTTP/1.1\r\n
#         [Expert Info (Chat/Sequence): GET /thsft/iFindService/StockHq/index/picturedata?&entry=gz&hqcode=603722&enddate=20240326&items=169 HTTP/1.1\r\n]
#         Request Method: GET
#         Request URI: /thsft/iFindService/StockHq/index/picturedata?&entry=gz&hqcode=603722&enddate=20240326&items=169
#             Request URI Path: /thsft/iFindService/StockHq/index/picturedata
#             Request URI Query: &entry=gz&hqcode=603722&enddate=20240326&items=169
#                 Request URI Query Parameter: &entry=gz
#                 Request URI Query Parameter: hqcode=603722
#                 Request URI Query Parameter: enddate=20240326
#                 Request URI Query Parameter: items=169
#         Request Version: HTTP/1.1
#     User-Agent: iFinD/1.10.12.404_682593258\r\n
#     Accept-Encoding: gzip,deflate\r\n
#      [truncated]Cookie: THSFT_USERID=zyzq3602; jgbsessid=8c16101ce87ac72c4790f7b2bc159d1e; userid=682593258; ticket=888d89327d7f7ffe236b22c9d2d049c5; user=Onp5enEzNjAyOjo6Ojo1NCwxMTAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwLDE1Ojo6OjY4MjU5MzI1
#     Host: ft.10jqka.com.cn\r\n
#     Connection: Keep-Alive\r\n
#     Cache-Control: no-cache\r\n
#     \r\n
#     [Full request URI: http://ft.10jqka.com.cn/thsft/iFindService/StockHq/index/picturedata?&entry=gz&hqcode=603722&enddate=20240326&items=169]
#     [HTTP request 1/1]
#     [Response in frame: 847]

# %%
import socket

def simulate_tcp_communication(server_ip, server_port, message):
    # 创建socket对象
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        # 连接到服务器
        s.connect((server_ip, server_port))
        
        # 发送数据
        s.sendall(message.encode())
        
        # 接收响应
        response = s.recv(1024)
        
        print("Received:", response.decode())

# 示例服务器IP地址和端口
server_ip = '8.132.233.144'  # 需要替换为实际的IP地址
server_port = 8601  # 需要替换为实际的端口号

# 构造的消息数据，需要根据实际情况进行调整
message = """CodeList=17(603721,);
DataType=19,223,224,225,226,227,228,229,230,237,238,259,260,261,262,134398,134399,134400,134401,134402,134403,134404,134405,331070,331077,331078,331079,331080,331124,331125,331126,331128,
DateTime=0(0-0)
LackTime=0,0,0,0,0,0,0,0
pageid=9354"""

# 调用函数进行TCP通信
simulate_tcp_communication(server_ip, server_port, message)
# Out:
# Received:

# %%
import socket

# 假设这是你从抓包工具中获取的十六进制数据字符串
hex_data = """

61676569643d393335340d0a
""".replace('\n', '').replace(' ', '')

# 将十六进制字符串转换为字节
bytes_data = bytes.fromhex(hex_data)

def send_raw_tcp_data(server_ip, server_port, data):
    # 创建一个socket对象
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        # 连接到服务器
        s.connect((server_ip, server_port))
        
        # 发送原始字节数据
        s.sendall(data)
        
        # （可选）接收服务器响应的数据
        data_received = s.recv(1024)
        print("Received:", data_received)

# 目标服务器的IP和端口
server_ip = '8.132.233.144'  # 需要替换为实际的IP地址
server_port = 8601  # 需要替换为实际的端口号

# 发送原始TCP数据
send_raw_tcp_data(server_ip, server_port, bytes_data)
# Out:
# Received: b''

# %%
from api.em.calendar import trading_days

days = trading_days(start_date='20230320')
days
# Out:
# ['20230320',
#  '20230321',
#  '20230322',
#  '20230323',
#  '20230324',
#  '20230327',
#  '20230328',
#  '20230329',
#  '20230330',
#  '20230331',
#  '20230403',
#  '20230404',
#  '20230406',
#  '20230407',
#  '20230410',
#  '20230411',
#  '20230412',
#  '20230413',
#  '20230414',
#  '20230417',
#  '20230418',
#  '20230419',
#  '20230420',
#  '20230421',
#  '20230424',
#  '20230425',
#  '20230426',
#  '20230427',
#  '20230428',
#  '20230504',
#  '20230505',
#  '20230508',
#  '20230509',
#  '20230510',
#  '20230511',
#  '20230512',
#  '20230515',
#  '20230516',
#  '20230517',
#  '20230518',
#  '20230519',
#  '20230522',
#  '20230523',
#  '20230524',
#  '20230525',
#  '20230526',
#  '20230529',
#  '20230530',
#  '20230531',
#  '20230601',
#  '20230602',
#  '20230605',
#  '20230606',
#  '20230607',
#  '20230608',
#  '20230609',
#  '20230612',
#  '20230613',
#  '20230614',
#  '20230615',
#  '20230616',
#  '20230619',
#  '20230620',
#  '20230621',
#  '20230626',
#  '20230627',
# ...

# %%
days[-1]
# Out:
# '20240401'

# %%
from api.jqka.limits import daily_cont, daily_limits_hot

test = daily_limits_hot(date=days[0])
test
# Out:
#    ind_code ind_name  ind_change  ulim_num  cont_num ind_height  \
# 0    885494     一带一路     -0.6278         6         2       5天5板
# 1    885494     一带一路     -0.6278         6         2       5天5板
# 2    885494     一带一路     -0.6278         6         2       5天5板
# 3    885494     一带一路     -0.6278         6         2       5天5板
# 4    885494     一带一路     -0.6278         6         2       5天5板
# ..      ...      ...         ...       ...       ...        ...
# 69   885741    中字头股票     -0.5317         3         1       2天2板
# 70   885741    中字头股票     -0.5317         3         1       2天2板
# 71   885595   央企国企改革     -0.6589         3         1       2天2板
# 72   885595   央企国企改革     -0.6589         3         1       2天2板
# 73   885595   央企国企改革     -0.6589         3         1       2天2板
#
#     ind_listed_days    code  name  price       tflim       tllim   change  \
# 0                 6  002323  雅博股份   3.00  1679279601  1679279601   9.8901
# ...

# %%
import datetime
import sqlite3

for day in days:
    data_iter = daily_limits_hot(date=day)
    data_iter.to_sql(con=sqlite3.connect())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       8     data_iter['date'] = datetime.datetime.strptime(day, '%Y%m%d')
#       9     res.append(data_iter)
# ---> 10 res = pd.concat(res)
#      11 res.to_sql(con=sqlite3.connect('cont.db'), if_exists='replace', index=False, name='cont')
#      12 res
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

res = pd.concat(res)
res.to_sql(con=sqlite3.connect('cont.db'), if_exists='replace', index=False, name='cont')
res
# Out:
#     height    code  name       date
# 0        5  000506  中润资源 2023-03-20
# 1        2  002051  中工国际 2023-03-20
# 2        2  002280  联络互动 2023-03-20
# 3        2  600895  张江高科 2023-03-20
# 0        3  002280  联络互动 2023-03-21
# ..     ...     ...   ...        ...
# 11       2  603843  正平股份 2024-04-01
# 12       2  603900  莱绅通灵 2024-04-01
# 13       2  603926  铁流股份 2024-04-01
# 14       2  605138  盛泰集团 2024-04-01
# 15       2  605198   安德利 2024-04-01
#
# [2510 rows x 4 columns]

# %%
res.sort_values(by=['height'], ascending=False)
# Out:
#     height    code  name       date
# 0       14  603178  圣龙股份 2023-10-25
# 0       13  603960  克来机电 2024-02-27
# 0       13  603178  圣龙股份 2023-10-24
# 0       13  603580  艾艾精工 2024-03-21
# 0       12  603178  圣龙股份 2023-10-23
# ..     ...     ...   ...        ...
# 8        2  605005  合兴股份 2023-11-28
# 7        2  600698  湖南天雁 2023-11-28
# 6        2  002856  美芝股份 2023-11-28
# 5        2  002058   威尔泰 2023-11-28
# 15       2  605198   安德利 2024-04-01
#
# [2510 rows x 4 columns]

# %%
res_final = []
for name in list(res['name'].unique()):
    name_iter = res[res['name'] == name]
    height_max = max(list(name_iter['height']))
    res_final.append(name_iter[name_iter['height'] == height_max])
res_final = pd.concat(res_final)
res_final.reset_index(drop=True, inplace=True)
res_final
# Out:
#       height    code  name       date
# 0          5  000506  中润资源 2023-03-20
# 1          2  002051  中工国际 2023-03-20
# 2          2  002051  中工国际 2023-04-17
# 3          4  002280  联络互动 2023-03-22
# 4          4  600895  张江高科 2023-09-11
# ...      ...     ...   ...        ...
# 1115       2  301022   海泰科 2024-04-01
# 1116       2  603843  正平股份 2024-04-01
# 1117       2  603900  莱绅通灵 2024-04-01
# 1118       2  603926  铁流股份 2024-04-01
# 1119       2  605138  盛泰集团 2024-04-01
#
# [1120 rows x 4 columns]

# %%
res_final.sort_values(by=['height', 'date'], ascending=False, inplace=True)
res_final.reset_index(inplace=True, drop=True)
res_final
# Out:
#       height    code  name       date
# 0         14  603178  圣龙股份 2023-10-25
# 1         13  603580  艾艾精工 2024-03-21
# 2         13  603960  克来机电 2024-02-27
# 3         11  000017  深中华A 2024-01-23
# 4         11  000628  高新发展 2023-11-02
# ...      ...     ...   ...        ...
# 1115       2  002323  雅博股份 2023-03-21
# 1116       2  002605  姚记科技 2023-03-21
# 1117       2  002803  吉宏股份 2023-03-21
# 1118       2  300291  百纳千成 2023-03-21
# 1119       2  002051  中工国际 2023-03-20
#
# [1120 rows x 4 columns]

# %%
res_final[res_final['height'] > 3].sort_values(by=['date'])
# Out:
#      height    code  name       date
# 120       5  000506  中润资源 2023-03-20
# 233       4  002280  联络互动 2023-03-22
# 232       4  002888  惠威科技 2023-03-27
# 231       4  601116  三江购物 2023-03-31
# 11        9  603291  联合水务 2023-04-07
# ..      ...     ...   ...        ...
# 24        7  600165  宁科生物 2024-03-28
# 122       4  603679  华体科技 2024-04-01
# 121       4  002769   普路通 2024-04-01
# 12        8  605180  华生科技 2024-04-01
# 61        5  603006  联明股份 2024-04-01
#
# [234 rows x 4 columns]

# %%
res_final_dict = {res_final.loc[i, 'name']: res_final.loc[i, 'height'] for i in range(len(res_final))}
res['height_max'] = 2
res['height_max'] = res['name'].apply(lambda x: res_final_dict[x])
res
# Out:
#     height    code  name       date  height_max
# 0        5  000506  中润资源 2023-03-20           5
# 1        2  002051  中工国际 2023-03-20           2
# 2        2  002280  联络互动 2023-03-20           4
# 3        2  600895  张江高科 2023-03-20           4
# 0        3  002280  联络互动 2023-03-21           4
# ..     ...     ...   ...        ...         ...
# 11       2  603843  正平股份 2024-04-01           2
# 12       2  603900  莱绅通灵 2024-04-01           2
# 13       2  603926  铁流股份 2024-04-01           2
# 14       2  605138  盛泰集团 2024-04-01           2
# 15       2  605198   安德利 2024-04-01           3
#
# [2510 rows x 5 columns]

# %%
res_plot = res[res['height_max'] >= 5]
res_plot
# Out:
#     height    code  name       date  height_max
# 0        5  000506  中润资源 2023-03-20           5
# 6        2  600280  中央商场 2023-03-21           6
# 1        2  002229  鸿博股份 2023-03-23           5
# 0        3  002229  鸿博股份 2023-03-24           5
# 0        8  603291  联合水务 2023-04-06           9
# ..     ...     ...   ...        ...         ...
# 4        3  603006  联明股份 2024-03-28           5
# 0        7  605180  华生科技 2024-03-29           8
# 1        4  603006  联明股份 2024-03-29           5
# 0        8  605180  华生科技 2024-04-01           8
# 1        5  603006  联明股份 2024-04-01           5
#
# [835 rows x 5 columns]

# %%
res_plot.sort_values(by=['name', 'date'], ascending=True, inplace=True)
res_plot
# Out:
# /var/folders/sp/_cfkztsj36z3g2vlh563p0100000gn/T/ipykernel_13688/1420263321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_plot.sort_values(by=['name', 'date'], ascending=True, inplace=True)
#     height    code  name       date  height_max
# 6        2  001300   三柏硕 2023-11-13           9
# 4        3  001300   三柏硕 2023-11-14           9
# 1        4  001300   三柏硕 2023-11-15           9
# 0        5  001300   三柏硕 2023-11-16           9
# 0        6  001300   三柏硕 2023-11-17           9
# ..     ...     ...   ...        ...         ...
# 47       2  603729  龙韵股份 2024-02-20           5
# 9        2  605086  龙高股份 2023-11-13           5
# 6        3  605086  龙高股份 2023-11-14           5
# 3        4  605086  龙高股份 2023-11-15           5
# 2        5  605086  龙高股份 2023-11-16           5
#
# ...

# %%
res_plot.reset_index(inplace=True, drop=True)

# %%
res_plot
# Out:
#      height    code  name       date  height_max
# 0         2  001300   三柏硕 2023-11-13           9
# 1         3  001300   三柏硕 2023-11-14           9
# 2         4  001300   三柏硕 2023-11-15           9
# 3         5  001300   三柏硕 2023-11-16           9
# 4         6  001300   三柏硕 2023-11-17           9
# ..      ...     ...   ...        ...         ...
# 830       2  603729  龙韵股份 2024-02-20           5
# 831       2  605086  龙高股份 2023-11-13           5
# 832       3  605086  龙高股份 2023-11-14           5
# 833       4  605086  龙高股份 2023-11-15           5
# 834       5  605086  龙高股份 2023-11-16           5
#
# [835 rows x 5 columns]

# %%
datetime.datetime.strftime(res_plot.loc[0, 'date'], '%Y%m%d')
# Out:
# '20231113'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 10))

for com in list(res_plot['name'].unique()):
    plot_iter = res_plot[res_plot['name'] == com]
    plot_iter.reset_index(inplace=True, drop=True)
    count = 0
    plot_iter['count'] = 0
    for k in range(len(plot_iter)):
        date_iter = datetime.datetime.strftime(plot_iter.loc[k, 'date'], '%Y%m%d')
        try:
            next_date = days[days.index(date_iter) + 1]
        except IndexError:
            continue
        try:
            if datetime.datetime.strftime(plot_iter.loc[k + 1, 'date'], '%Y%m%d') != next_date:
                count += 1
                plot_iter.loc[k + 1:, 'count'] = count
        except (IndexError, KeyError):
            continue
    counts = list(plot_iter['count'].unique())
    for count_iter in counts:
        plt.plot(plot_iter[plot_iter['count'] == count_iter]['date'], plot_iter[plot_iter['count'] == count_iter]['height'])
plt.savefig('连板统计.png', dpi=600)
# Out:
# /var/folders/sp/_cfkztsj36z3g2vlh563p0100000gn/T/ipykernel_13688/406257419.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_iter['count'] = 0
# /var/folders/sp/_cfkztsj36z3g2vlh563p0100000gn/T/ipykernel_13688/406257419.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_iter['count'] = 0
# /var/folders/sp/_cfkztsj36z3g2vlh563p0100000gn/T/ipykernel_13688/406257419.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.savefig('连板统计.png', dpi=800)

# %%
plot_iter.loc[k, 'date']
# Out:
# Timestamp('2023-11-13 00:00:00')

# %%
date_iter
# Out:
# '20230013'
